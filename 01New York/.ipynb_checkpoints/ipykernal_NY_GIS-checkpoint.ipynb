# %% [markdown]
# <h1><center> Individual Data Noise Creation <br><br>
# <center> Scikit Mobility and DB Noise<br><br>
# Wendy Shi</center></center>

# %% [markdown]
# # TOC
#
# - [County Level FIP](#County-Level-FIP-Code)
# - [Individual Data](#Individual-Data)
# - [Census Tract Shape File](#Census-Tract-Shape-File)
# - [Grouping](#Groupping)
#     - [DB Noise](#DP_noise)
#     - [Testing](#Testing)
# - [Matrix Transformation](#Group-by-county)

# %% [markdown]
# # Preparation

# %%
#Preparation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# # County Level FIP Code

# %%
column_names = ['S', 'E', 'I', 'R']
Seeding = pd.read_csv("../../Data/seed_1503_seed_corrected_undereporting_CDC_corrected_v3.txt",
                     delimiter=' ',
                      names=column_names)
print(Seeding.shape)
Seeding.tail(3)
# Out:
# (2327, 4)
#           S  E  I  R
# 2324  42158  0  0  0
# 2325  23347  0  0  0
# 2326  20441  0  0  0

# %%
node_dict = pd.read_csv("../../Data/nodes_considered.csv")
node_dict = node_dict.drop(columns = ['index'])
print(node_dict.shape)
node_dict.tail(3)
# Out:
# (2327, 1)
#       GEO_ID
# 2324   56037
# 2325   56039
# 2326   56041

# %%
node_dict['Population'] = Seeding['S']
node_dict.tail(5)
# Out:
#       GEO_ID  Population
# 2322   56029       29656
# 2323   56033       30996
# 2324   56037       42158
# 2325   56039       23347
# 2326   56041       20441

# %%
#Check if node dictionary size equals to size of E, and see if they all have population larger than 11,000
desired = node_dict[node_dict['Population'] > 11000]
print(desired.shape)

node_dict["GEO_ID"] = node_dict["GEO_ID"].apply(lambda x: f"{int(x):05d}")

#rename column
rename = {'GEO_ID' : 'GEOID'}
node_dict = node_dict.rename(columns = rename)
node_dict.head(3)
# Out:
# (2327, 2)
#    GEOID  Population
# 0  01001       58877
# 1  01003      233140
# 2  01005       25180

# %%
node_dict['state'] = node_dict['GEOID'].str[:2]
node_dict['index'] = range(len(node_dict))
node_dict.head(3)
# Out:
#    GEOID  Population state  index
# 0  01001       58877    01      0
# 1  01003      233140    01      1
# 2  01005       25180    01      2

# %%
new_york = node_dict[node_dict['state'] == '36']

#Index list--------------This is the one that check if weight matrix is in the same order as SEIR initial condition
E_ny_index = new_york['GEOID'].to_list()

#Population list
pop_list = new_york['Population'].tolist()

#Print the dataset
print(new_york.shape)
new_york.head(3)
# Out:
# (61, 4)
#       GEOID  Population state  index
# 1318  36001      314368    36   1318
# 1319  36003       46373    36   1319
# 1320  36005     1466382    36   1320

# %%
index = new_york['index'].tolist()
print(index)
# Out:
# [1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378]

# %% [markdown]
# # Original Matrix for reference

# %%
#Open the 12 weight matrix
column_names = ['origin', 'destination', 'count', 'weight']
for i in range(12):
    n = i +1
    
    df = pd.read_csv(f"../../Data/monthly_matrix_sd_county_month{n}_county.txt", 
                     delimiter=' ', names=column_names)
    
    #Making sure all origin and destination are states in New York
    df = df[(df['origin'].isin(index)) & (df['destination'].isin(index))]
    
    # Store the modified DataFrame
    globals()[f'wt_mt{n}'] = df

# %%
wt_mt12.head(3)
# Out:
#         origin  destination  count    weight
# 181402    1318         1321     12  0.000872
# 181403    1319         1321     12  0.002364
# 181404    1320         1321     12  0.000080

# %%
#Turn each data into a matrix
#Transform the dataframe to a matrix with pivot table
for i in range(12):
    n = i+1
    matrix = globals()[f'wt_mt{n}'].pivot_table(index='origin', 
                                                columns='destination', 
                                                values= 'weight', fill_value=0)
    matrix = matrix.reset_index()
    matrix = matrix.drop(columns = ["origin"]) #drop the origin column
    globals()[f'matrix{n}'] = matrix

# %%
for i in range(12):
    n = i +1
    count_df = globals()[f'matrix{n}'].multiply(pop_list, axis=0)
    globals()[f'count_df{n}'] = count_df

# %%
average_count_df = sum(globals()[f'count_df{i}'] for i in range(1, 13)) / 12
print(average_count_df.shape)
average_count_df.head(3)
# Out:
# (61, 61)
# destination           1318          1319          1320        1321  \
# 0            246343.007662     32.453645  5.135209e+02  221.704544
# 1                40.374258  27785.635801  3.842220e+01   43.617012
# 2               483.785867     37.393907  1.130076e+06  208.118470
#
# destination         1322       1323        1324        1325       1326  \
# 0              33.435578  62.432000   28.849326   47.490592  52.924327
# 1            3213.033780  26.448097  146.772590  148.111324  16.262851
# 2              26.220327  36.128656   52.054441   32.947582  27.962298
#
# destination        1327  ...        1369       1370       1371        1372  \
# 0            194.264817  ...   82.315085  39.285608  60.861844  591.544807
# 1             19.150394  ...   15.887173  31.500426  38.986176   19.552823
# 2             78.183617  ...  333.364563  25.122224  63.347167  470.684167
#
# destination         1373        1374       1375          1376        1377  \
# 0            1306.547995  371.765060  29.734195    349.420890   17.666349
# 1              19.414883   15.444189  44.260831     23.520586  512.541075
# 2             161.448398   24.899346  20.981249  48484.315002   15.427956
#
# destination       1378
# 0            27.451021
# 1            52.353649
# 2            22.276248
#
# [3 rows x 61 columns]

# %%
#Turn count to weight
divisor = [average_count_df.iloc[i].sum() for i in range(61)]
average_wt_mt = average_count_df.div(divisor, axis=0)
average_wt_mt.head(3)
# Out:
# destination      1318      1319      1320      1321      1322      1323  \
# 0            0.841830  0.000111  0.001755  0.000758  0.000114  0.000213
# 1            0.001071  0.737019  0.001019  0.001157  0.085226  0.000702
# 2            0.000347  0.000027  0.811352  0.000149  0.000019  0.000026
#
# destination      1324      1325      1326      1327  ...      1369      1370  \
# 0            0.000099  0.000162  0.000181  0.000664  ...  0.000281  0.000134
# 1            0.003893  0.003929  0.000431  0.000508  ...  0.000421  0.000836
# 2            0.000037  0.000024  0.000020  0.000056  ...  0.000239  0.000018
#
# destination      1371      1372      1373      1374      1375      1376  \
# 0            0.000208  0.002021  0.004465  0.001270  0.000102  0.001194
# 1            0.001034  0.000519  0.000515  0.000410  0.001174  0.000624
# 2            0.000045  0.000338  0.000116  0.000018  0.000015  0.034810
#
# destination      1377      1378
# 0            0.000060  0.000094
# 1            0.013595  0.001389
# 2            0.000011  0.000016
#
# [3 rows x 61 columns]

# %%
average_wt_mt_np = average_wt_mt.to_numpy()

# %%
average_wt_mt_np[0][0]
# Out:
# 0.8418301374070274

# %%
Pii_ori = [average_wt_mt_np[i][i] for i in range(61)]

# %%
data = Pii_ori 
mean_value = sum(data) / len(data)  # Mean
median_value = statistics.median(data)  # Median
min_value = min(data)  # Min
max_value = max(data)  # Max

# Output
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Min: {min_value}")
print(f"Max: {max_value}")
print(f"Length of the list: {len(Pii_ori)}")
# Out:
# Mean: 0.8043316871173353
# Median: 0.7917201349186358
# Min: 0.6594295764342875
# Max: 0.9379360744803336
# Length of the list: 61

# %%
print(len(Pii_ori))
# Out:
# 61

# %% [markdown]
# # Individual Data

# %% [markdown]
# ## Different Layers of Census Data
#
# - State (2 digit)
# - County (5 digit)
# - Census Tracts (4 digits)
# - Census Block Groups
# - Census tracts

# %%
data = pd.read_csv("NY_4Week_10000_realpop.csv")
data = data.drop(columns = 'Unnamed: 0')
print(data.shape)
data.head()
# Out:
# (4690333, 4)
#    uid                    datetime        lat        lng
# 0    1  2020-03-01 00:00:00.000000  40.735878 -73.899228
# 1    1  2020-03-01 06:25:08.573311  40.737657 -73.907013
# 2    1  2020-03-01 08:04:00.153349  40.735878 -73.899228
# 3    1  2020-03-01 09:17:51.635022  40.743086 -73.880599
# 4    1  2020-03-01 10:55:47.394269  40.735878 -73.899228

# %%
indi_visit_list = []
for i in range(10000):
    id_num = i+1
    #if i % 4000 == 0:
    #    print(i)
    indi_sub = data[data['uid'] == id_num]
    length = len(indi_sub)
    indi_visit_list.append(length)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(indi_visit_list, fill=True)
plt.xlabel('Total visit')
plt.ylabel('Density')
plt.title('Density Plot')
plt.show()

min_val = np.min(indi_visit_list)
P5 = np.percentile(indi_visit_list, 5)
median = np.median(indi_visit_list)
P95 = np.percentile(indi_visit_list, 95)
max_val = np.max(indi_visit_list)

print(f"Min: {min_val}")
print(f"5%: {P5}")
print(f"Median: {median}")
print(f"95%: {P95}")
print(f"Max: {max_val}")
# Out:
# Min: 303
# 5%: 404.0
# Median: 470.0
# 95%: 531.0
# Max: 606

# %% [markdown]
# # Census Tract Shape File

# %% [markdown]
# https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.html
# - Go to Data
# - Mapping file
# - TIGER/Line Geodatabases (GIS)
#
#
# Here's the county level shape file:
# https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html

# %%
#Note that geopandas only works in ipykernel environment
import geopandas as gpd
from shapely.geometry import Point
from shapely.wkt import loads

# %% [markdown]
# ## trying census block group this time!

# %%
#url = "https://www2.census.gov/geo/tiger/TIGER2020/BG/tl_2020_36_bg.zip"
#tracts = gpd.read_file(url)[["GEOID", "geometry"]]
tracts = gpd.read_file("tl_2020_36_bg/tl_2020_36_bg.shp")[["GEOID", "geometry"]]
print(tracts.columns)
print(tracts.shape)
tracts.head(1)
# Out:
# Index(['GEOID', 'geometry'], dtype='object')
# (16070, 2)
#           GEOID                                           geometry
# 0  360191010003  POLYGON ((-73.47596 44.69761, -73.47489 44.697...

# %%
#To test if they are all New York Data
test = tracts.copy()
test['state'] = test['GEOID'].str[:2]
unique_state = test['state'].unique().tolist()
unique_state
# Out:
# ['36']

# %%
tracts.iloc[1,1]
# Out:
# <POLYGON ((-73.555 44.877, -73.555 44.878, -73.555 44.881, -73.555 44.885, -...>

# %% [markdown]
# ## Individual trajectory data

# %%
print(data.shape)
data.head()
# Out:
# (4690333, 4)
#    uid                    datetime        lat        lng
# 0    1  2020-03-01 00:00:00.000000  40.735878 -73.899228
# 1    1  2020-03-01 06:25:08.573311  40.737657 -73.907013
# 2    1  2020-03-01 08:04:00.153349  40.735878 -73.899228
# 3    1  2020-03-01 09:17:51.635022  40.743086 -73.880599
# 4    1  2020-03-01 10:55:47.394269  40.735878 -73.899228

# %%
# Convert latitude/longitude into Point geometry
geometry = [Point(xy) for xy in zip(data["lng"], data["lat"])] #Convert coordinate to points

# Create a GeoDataFrame with the same CRS as the Census Tract shapefile
points_gdf = gpd.GeoDataFrame(data, geometry=geometry, crs="EPSG:4326")

points_gdf.head()  # Check that geometry was created correctly
# Out:
#    uid                    datetime        lat        lng  \
# 0    1  2020-03-01 00:00:00.000000  40.735878 -73.899228
# 1    1  2020-03-01 06:25:08.573311  40.737657 -73.907013
# 2    1  2020-03-01 08:04:00.153349  40.735878 -73.899228
# 3    1  2020-03-01 09:17:51.635022  40.743086 -73.880599
# 4    1  2020-03-01 10:55:47.394269  40.735878 -73.899228
#
#                      geometry
# 0  POINT (-73.89923 40.73588)
# 1  POINT (-73.90701 40.73766)
# 2  POINT (-73.89923 40.73588)
# 3  POINT (-73.88060 40.74309)
# 4  POINT (-73.89923 40.73588)

# %%
# Convert Census Tract shapefile to the same CRS as the points
# This is to make sure both data use EPSG:4326
tracts = tracts.to_crs(points_gdf.crs)
tracts.head()
# Out:
#           GEOID                                           geometry
# 0  360191010003  POLYGON ((-73.47596 44.69761, -73.47489 44.697...
# 1  360191002001  POLYGON ((-73.55525 44.87744, -73.55521 44.878...
# 2  360191022003  POLYGON ((-73.46084 44.68186, -73.46079 44.682...
# 3  360191008002  POLYGON ((-73.52782 44.71511, -73.52781 44.715...
# 4  360290090082  POLYGON ((-78.73283 42.99889, -78.73243 42.998...

# %%
print("Tracts CRS:", tracts.crs)
print("Points CRS:", points_gdf.crs)
# Out:
# Tracts CRS: EPSG:4326
# Points CRS: EPSG:4326

# %%
#Perform spacial join
joined_gdf = gpd.sjoin(points_gdf, tracts, how="left", predicate="within")
print(joined_gdf.shape)
joined_gdf.head(3)
# Out:
# (4690333, 7)
#    uid                    datetime        lat        lng  \
# 0    1  2020-03-01 00:00:00.000000  40.735878 -73.899228
# 1    1  2020-03-01 06:25:08.573311  40.737657 -73.907013
# 2    1  2020-03-01 08:04:00.153349  40.735878 -73.899228
#
#                      geometry  index_right         GEOID
# 0  POINT (-73.89923 40.73588)         7368  360810243003
# 1  POINT (-73.90701 40.73766)          185  360810245004
# 2  POINT (-73.89923 40.73588)         7368  360810243003

# %%
joined_gdf['datetime'] = pd.to_datetime(joined_gdf['datetime'])
joined_gdf['day'] = joined_gdf['datetime'].dt.day
joined_gdf.head(3)
# Out:
#    uid                   datetime        lat        lng  \
# 0    1 2020-03-01 00:00:00.000000  40.735878 -73.899228
# 1    1 2020-03-01 06:25:08.573311  40.737657 -73.907013
# 2    1 2020-03-01 08:04:00.153349  40.735878 -73.899228
#
#                      geometry  index_right         GEOID  day
# 0  POINT (-73.89923 40.73588)         7368  360810243003    1
# 1  POINT (-73.90701 40.73766)          185  360810245004    1
# 2  POINT (-73.89923 40.73588)         7368  360810243003    1

# %% [markdown]
# # Groupping

# %% [markdown]
# ## Here's Where to add noise

# %%
#Grouped
grouped_counts = joined_gdf.groupby(['uid', 'day','GEOID']).size().reset_index()
rename = {0 : 'Count'}
grouped_counts = grouped_counts.rename(columns = rename)
grouped_counts.head(10)
# Out:
#    uid  day         GEOID  Count
# 0    1    1  360810243003      5
# 1    1    1  360810245004      4
# 2    1    1  360810271013      1
# 3    1    1  360810515001      1
# 4    1    1  360810661001      1
# 5    1    1  361190071001      2
# 6    1    1  361190100001      1
# 7    1    2  360050267023      1
# 8    1    2  360810117004      1
# 9    1    2  360810145002      1

# %%
grouped_counts.insert(3, "County", grouped_counts['GEOID'].str[:5]) #State + county is a five digit code

#One individual has about 30 unique locations
print(grouped_counts.shape)
grouped_counts.head(5)
# Out:
# (3627071, 5)
#    uid  day         GEOID County  Count
# 0    1    1  360810243003  36081      5
# 1    1    1  360810245004  36081      4
# 2    1    1  360810271013  36081      1
# 3    1    1  360810515001  36081      1
# 4    1    1  360810661001  36081      1

# %% [markdown]
# # DP Noise

# %%
import opendp.prelude as dp
dp.enable_features("contrib")

#The Loop
#privacy_budget = [0.5, 0.1, 0.05, 0.01, 0.005, 0.001]
#name = ['P5','P1','P05','P01','P005','P001']
#privacy_budget = [0.8, 0.5, 0.3, 0.1, 0.05]
#name = ['P8','P5','P3','P1','P05']
privacy_budget = [0.01,0.005]
name = ['P01','P005']

# Ensure the 'Count' column is float before applying DP noise
grouped_counts['Count'] = grouped_counts['Count'].astype(int).copy()

for i in range(len(privacy_budget)):
    print(i)
    epsilon = privacy_budget[i] #Privacy budget
    sensitivity = 1
    scale = sensitivity / epsilon
    
    # Create the Laplace mechanism
    laplace_mechanism = dp.m.make_laplace(
        dp.atom_domain(T=int), dp.absolute_distance(T=int), scale)
    
    #Define the Laplace function
    def apply_dp_noise(count):
        return laplace_mechanism(count)
    
    #Name for the new column
    text = name[i]
    
    grouped_counts[f'Count_{text}'] = grouped_counts['Count'].apply(lambda x: max(laplace_mechanism(x), 0))
# Out:
# 0
# 1

# %%
grouped_counts.head(10)
# Out:
#    uid  day         GEOID County  Count  Count_P01  Count_P005
# 0    1    1  360810243003  36081      5         22         239
# 1    1    1  360810245004  36081      4          0         253
# 2    1    1  360810271013  36081      1          0           0
# 3    1    1  360810515001  36081      1          0          14
# 4    1    1  360810661001  36081      1          0           0
# 5    1    1  361190071001  36119      2          0         324
# 6    1    1  361190100001  36119      1         83          88
# 7    1    2  360050267023  36005      1        264         306
# 8    1    2  360810117004  36081      1          0           0
# 9    1    2  360810145002  36081      1         97           0

# %% [markdown]
# #

# %% [markdown]
# # Home Location

# %%
home = pd.read_csv("Home_location_4Week_10000_NY_realpop.csv")
home = home.drop(columns = 'Unnamed: 0')
print(home.shape)
home.head()
# Out:
# (10000, 3)
#    uid        lat        lng
# 0    1  40.735878 -73.899228
# 1    2  43.192236 -77.571473
# 2    3  41.008568 -73.733575
# 3    4  42.101347 -77.964181
# 4    5  40.776276 -73.958993

# %%
# Convert latitude/longitude into Point geometry
geometry = [Point(xy) for xy in zip(home["lng"], home["lat"])] #Convert coordinate to points

# Create a GeoDataFrame with the same CRS as the Census Tract shapefile
home_points_gdf = gpd.GeoDataFrame(home, geometry=geometry, crs="EPSG:4326")

home_points_gdf.head()  # Check that geometry was created correctly
# Out:
#    uid        lat        lng                    geometry
# 0    1  40.735878 -73.899228  POINT (-73.89923 40.73588)
# 1    2  43.192236 -77.571473  POINT (-77.57147 43.19224)
# 2    3  41.008568 -73.733575  POINT (-73.73357 41.00857)
# 3    4  42.101347 -77.964181  POINT (-77.96418 42.10135)
# 4    5  40.776276 -73.958993  POINT (-73.95899 40.77628)

# %%
print("Tracts CRS:", tracts.crs)
print("Points CRS:", home_points_gdf.crs)
# Out:
# Tracts CRS: EPSG:4326
# Points CRS: EPSG:4326

# %%
#tracts.head(3)

# %%
home_joined_gdf = gpd.sjoin(home_points_gdf, tracts, how="left", predicate="within")
print(home_joined_gdf.shape)
home_joined_gdf.head(3)
# Out:
# (10000, 6)
#    uid        lat        lng                    geometry  index_right  \
# 0    1  40.735878 -73.899228  POINT (-73.89923 40.73588)         7368
# 1    2  43.192236 -77.571473  POINT (-77.57147 43.19224)        14259
# 2    3  41.008568 -73.733575  POINT (-73.73357 41.00857)         3614
#
#           GEOID
# 0  360810243003
# 1  360550109013
# 2  361190097033

# %%
#home geoid at the county level
home_joined_gdf['home_geoid'] = home_joined_gdf['GEOID'].str[:5] 
home_joined_gdf.head(3)
# Out:
#    uid        lat        lng                    geometry  index_right  \
# 0    1  40.735878 -73.899228  POINT (-73.89923 40.73588)         7368
# 1    2  43.192236 -77.571473  POINT (-77.57147 43.19224)        14259
# 2    3  41.008568 -73.733575  POINT (-73.73357 41.00857)         3614
#
#           GEOID home_geoid
# 0  360810243003      36081
# 1  360550109013      36055
# 2  361190097033      36119

# %% [markdown]
# ### This is where home list is computed!!! Important!!!

# %%
#Home list------------------------------------------------!!------------!!-----------
home_list = home_joined_gdf['home_geoid'].tolist()
len(home_list)
# Out:
# 10000

# %%
home = home_joined_gdf[home_joined_gdf['uid'] == 1]['GEOID'][0]
home
# Out:
# '360810243003'

# %%
us_shape_file = pd.read_csv("../../Data/us_shapefile_county.csv")

#rename column
rename = {"FIPS code" : "GEOID"}
us_shape_file = us_shape_file.rename(columns = rename)
us_shape_file["GEOID"] = us_shape_file["GEOID"].apply(lambda x: f"{int(x):05d}")
us_shape_file = us_shape_file[['GEOID','pop2020']].copy()
us_shape_file.tail(3)
# Out:
#       GEOID    pop2020
# 3106  06037  9989165.0
# 3107  46113    14309.0
# 3108  51515     6599.0

# %%
home_groped= home_joined_gdf.groupby('home_geoid').size().reset_index(name='Count')
rename = {'home_geoid' :'GEOID'}
home_groped = home_groped.rename(columns = rename)
home_groped.head(3)
# Out:
#    GEOID  Count
# 0  36001    167
# 1  36003     20
# 2  36005    824

# %%
home_merged = pd.merge(us_shape_file, home_groped, on = 'GEOID', how = 'inner')
home_merged.head(3)
# Out:
#    GEOID  pop2020  Count
# 0  36097  17857.0      8
# 1  36123  24709.0     11
# 2  36049  26538.0      5

# %%
import matplotlib.pyplot as plt

plt.scatter(home_merged['pop2020'], home_merged['Count'], color='blue', alpha=0.6)


plt.xscale('log')      
plt.yscale('log')

# Labels and Title
#plt.xlim([0, 100000]) 
#plt.ylim([0, 100]) 

# Fit linear regression model (1st-degree polynomial for a linear fit)
slope, intercept = np.polyfit(home_merged['pop2020'], home_merged['Count'], 1)
# Generate fitted values
x_vals = np.linspace(home_merged['pop2020'].min(), home_merged['pop2020'].max(), 100)
y_vals = slope * x_vals + intercept

# Plot regression line
plt.plot(x_vals, y_vals, color='red', linewidth=2, label='Regression Line',  linestyle='--')



#Lables
plt.xlabel('County Population')
plt.ylabel('Number of Home Location')
plt.title('County Population vs Home Location')

# Show Plot
#plt.show()
#plt.savefig("county_vs_home_location_all.png", dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'County Population vs Home Location')

# %% [markdown]
# #

# %% [markdown]
# # Testing: Places visited the most
#
# ## Individual Data: transform this into origin and destination

# %%
print(grouped_counts.shape)
grouped_counts.head(10)
# Out:
# (3627071, 7)
#    uid  day         GEOID County  Count  Count_P01  Count_P005
# 0    1    1  360810243003  36081      5         22         239
# 1    1    1  360810245004  36081      4          0         253
# 2    1    1  360810271013  36081      1          0           0
# 3    1    1  360810515001  36081      1          0          14
# 4    1    1  360810661001  36081      1          0           0
# 5    1    1  361190071001  36119      2          0         324
# 6    1    1  361190100001  36119      1         83          88
# 7    1    2  360050267023  36005      1        264         306
# 8    1    2  360810117004  36081      1          0           0
# 9    1    2  360810145002  36081      1         97           0

# %%
person_id = grouped_counts["uid"].unique().tolist()
len(person_id)
# Out:
# 10000

# %%
# Transform this into a location, destination count matrix
# Make sure index start with 1 when subsetting
person = grouped_counts[grouped_counts['uid'] == person_id[0]].reset_index().copy() 
person = person.drop(columns = ['index'])
#home_idx = person['Count'].idxmax()
#print(home_idx)

#Origin = person.iloc[home_idx, 2] #Print county code for home
Origin = home_list[0]
Origin
# Out:
# '36081'

# %%
person.head(3)
# Out:
#    uid  day         GEOID County  Count  Count_P01  Count_P005
# 0    1    1  360810243003  36081      5         22         239
# 1    1    1  360810245004  36081      4          0         253
# 2    1    1  360810271013  36081      1          0           0

# %%
person.insert(3, "Origin", Origin)

#rename column
rename = {'County': 'Destination'}
person = person.rename(columns = rename)
person.head(5)
# Out:
#    uid  day         GEOID Origin Destination  Count  Count_P01  Count_P005
# 0    1    1  360810243003  36081       36081      5         22         239
# 1    1    1  360810245004  36081       36081      4          0         253
# 2    1    1  360810271013  36081       36081      1          0           0
# 3    1    1  360810515001  36081       36081      1          0          14
# 4    1    1  360810661001  36081       36081      1          0           0

# %%
person.head(20)
# Out:
#     uid  day         GEOID Origin Destination  Count  Count_P01  Count_P005
# 0     1    1  360810243003  36081       36081      5         22         239
# 1     1    1  360810245004  36081       36081      4          0         253
# 2     1    1  360810271013  36081       36081      1          0           0
# 3     1    1  360810515001  36081       36081      1          0          14
# 4     1    1  360810661001  36081       36081      1          0           0
# 5     1    1  361190071001  36081       36119      2          0         324
# 6     1    1  361190100001  36081       36119      1         83          88
# 7     1    2  360050267023  36081       36005      1        264         306
# 8     1    2  360810117004  36081       36081      1          0           0
# 9     1    2  360810145002  36081       36081      1         97           0
# 10    1    2  360810243003  36081       36081      2         22           0
# 11    1    2  360810245004  36081       36081      1         78           0
# 12    1    2  360810661001  36081       36081      1        104         531
# 13    1    3  360050267021  36081       36005      1          0           0
# 14    1    3  360050267023  36081       36005      1          0           0
# 15    1    3  360050269001  36081       36005      1        196           0
# 16    1    3  360470183003  36081       36047      1          0           0
# 17    1    3  360470275002  36081       36047      1          0           0
# 18    1    3  360470275004  36081       36047      1        553         308
# 19    1    3  360810243003  36081       36081      3         46           0

# %% [markdown]
# #

# %% [markdown]
# # The Loop

# %%
print(grouped_counts.shape)
grouped_counts.head(5)
# Out:
# (3627071, 7)
#    uid  day         GEOID County  Count  Count_P01  Count_P005
# 0    1    1  360810243003  36081      5         22         239
# 1    1    1  360810245004  36081      4          0         253
# 2    1    1  360810271013  36081      1          0           0
# 3    1    1  360810515001  36081      1          0          14
# 4    1    1  360810661001  36081      1          0           0

# %% [markdown]
# ### Assign home locaton to each individual

# %%
# Enpty Data Frame
ori_des_df = pd.DataFrame()
person_id = grouped_counts["uid"].unique().tolist()

#The Loop
for i in range(len(person_id)):
    
    if i % 4000 == 0:
        print(i)
    
    #Reset_index: This makes sure that everytime we do the subset, index start with 1
    person = grouped_counts[grouped_counts['uid'] == person_id[i]].reset_index().copy()
    person = person.drop(columns = ['index']) #since it create a separate column of index, we drop it!
    
    #Index Max to find home location
    #home_idx = person['Count'].idxmax()
    #Origin = person.iloc[home_idx, 2] #Print 【county】 code for home (Origin)
    
    #Use existing data to find home location
    Origin = home_list[i]
    
    #Insert Origin, shift county to the right as 'Destination'
    person.insert(3, "Origin", Origin)
    
    #rename column
    rename = {'County': 'Destination'}
    person = person.rename(columns = rename)
    
    #Concat the result
    #Note that each row are count for one census block, convert them into origin and destinaion
    ori_des_df = pd.concat([ori_des_df, person], axis = 0)
# Out:
# 0
# 4000
# 8000

# %%
print(ori_des_df.shape)
ori_des_df.head(3)
#ori_des_df.to_excel("ori_des_df.xlsx")
# Out:
# (3627071, 8)
#    uid  day         GEOID Origin Destination  Count  Count_P01  Count_P005
# 0    1    1  360810243003  36081       36081      5         22         239
# 1    1    1  360810245004  36081       36081      4          0         253
# 2    1    1  360810271013  36081       36081      1          0           0

# %% [markdown]
# # Group by county: Save it as different dataframe

# %% [markdown]
# ### Average Matrix Epsilon

# %%
def avg_mt_epsilon(Count):
    
    '''
    Calculating average mobility matrix for each day (1–30).
    This returns a dictionay of Daily Matrix
    '''
    Matrix_dict = {}

    for i in range(30):
        n = i + 1
        df = ori_des_df[ori_des_df['day'] == n]
        county_group = df.groupby(['Origin', 'Destination'])[Count].sum().reset_index()

        count_Matrix = county_group.pivot_table(index='Origin', 
                                                columns='Destination', 
                                                values= Count, 
                                                fill_value=0)
        
        #This is a new line of code added by ChatGTP
        count_Matrix = count_Matrix.sort_index().sort_index(axis=1)

        origin_list = count_Matrix.index.tolist()
        destination_list = count_Matrix.columns.tolist()
        #This is just to ensure if the row index and column index are in the same orde
        #As well as to ensure they also equals to the initial SEIR condition county order
        #If nothing goes wrong the loop will not print anything

        if origin_list != destination_list:
            print(f'Day {n}: origin list ≠ destination list')

        if origin_list != E_ny_index:
            print(f'Day {n}: origin list ≠ SEIR initial condition list')

        Matrix = count_Matrix.reset_index(drop=True)
        Matrix_dict[n] = Matrix

    return Matrix_dict

# %% [markdown]
# ### Daily Average Matrix

# %%
def daily_avg_wtmt(Matrix_dict):
    
    '''
    This function compute the daily average mobility matrix
    '''
    total_visit = Matrix_dict[1].copy()
    
    for i in range(1, 30):
        n = i + 1 #n therefore starts from 2
        #print(n)
        
        if n % 10 == 0:
            print(n)
            
        total_visit += Matrix_dict[n]
        
    daily_avg_visit = total_visit/30
    
    divisor = [daily_avg_visit.iloc[i].sum() for i in range(61)]
    average_wt_mt = daily_avg_visit.div(divisor, axis=0)
    
    return average_wt_mt

# %% [markdown]
# # Saving the Weight Matrix

# %%
Matrix_dict = avg_mt_epsilon('Count_P005')
Matrix_dict[1].head(3)
# Out:
# Destination  36001  36003   36005  36007  36009  36011  36013  36015  36017  \
# 0            85597      0    1008      0      0      0     42      0      0
# 1                0   3460      13      0      0      0      0    578      0
# 2               52      0  512815    134    198      0      0    523    176
#
# Destination  36019  ...  36105  36107  36109  36111  36113  36115  36117  \
# 0                0  ...      0      0      0   1606    527    241      0
# 1                0  ...      0      0     69      0      0      0      0
# 2              210  ...    849      0      0    232      0      0      0
#
# Destination  36119  36121  36123
# 0             1294      0      0
# 1                0    738      0
# 2            41972      0     58
#
# [3 rows x 61 columns]

# %%
daily_avg = daily_avg_wtmt(Matrix_dict)
daily_avg.head(3)
# Out:
# 10
# 20
# 30
# Destination     36001     36003     36005     36007     36009     36011  \
# 0            0.628493  0.000000  0.007168  0.000178  0.000040  0.000258
# 1            0.008590  0.167846  0.026250  0.001705  0.036734  0.001489
# 2            0.000226  0.000000  0.660122  0.001008  0.000204  0.000040
#
# Destination     36013     36015     36017     36019  ...     36105     36107  \
# 0            0.001956  0.000000  0.000160  0.000445  ...  0.000431  0.000061
# 1            0.014596  0.043979  0.000907  0.000000  ...  0.000843  0.000770
# 2            0.000000  0.000878  0.000283  0.000084  ...  0.000556  0.000082
#
# Destination     36109     36111     36113     36115     36117     36119  \
# 0            0.000347  0.005316  0.003874  0.002294  0.000215  0.008058
# 1            0.009454  0.002438  0.000000  0.000201  0.007340  0.006975
# 2            0.000299  0.000329  0.000227  0.000131  0.000013  0.044624
#
# Destination         36121     36123
# 0            0.000000e+00  0.000052
# 1            1.176205e-02  0.002837
# 2            3.952750e-07  0.000095
#
# [3 rows x 61 columns]

# %%
# Calculations
import statistics

average_wt_mt_np = daily_avg.to_numpy()
Pii_skmob = [average_wt_mt_np[i][i] for i in range(61)]


data = Pii_skmob 
mean_value = sum(data) / len(data)  # Mean
median_value = statistics.median(data)  # Median
min_value = min(data)  # Min
max_value = max(data)  # Max

# Output
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Min: {min_value}")
print(f"Max: {max_value}")
# Out:
# Mean: 0.41452394829008365
# Median: 0.4146584062952463
# Min: 0.10124721439859409
# Max: 0.8941700823700675

# %%
daily_avg.to_csv("NY_P005_indi.csv")

# %% [markdown]
# # Average Count Matrix for Aggregated Data Generation

# %%
total_visit = Matrix_dict[1].copy()
    
for i in range(1, 30):
    n = i + 1 #n therefore starts from 2
    #print(n)
    
    if n % 10 == 0:
        print(n)
            
    total_visit += Matrix_dict[n]
        
daily_avg_visit = total_visit/30
# Out:
# 10
# 20
# 30

# %%
daily_avg_visit.to_excel("daily_avg_visit_indi.xlsx")
daily_avg_visit.head()
# Out:
# Destination        36001      36003        36005        36007       36009  \
# 0            1707.533333   0.000000    17.033333     0.600000    0.066667
# 1               3.100000  68.666667     7.066667     0.366667   11.833333
# 2               1.566667   0.000000  8835.166667    10.333333    4.500000
# 3               4.366667   0.533333    17.766667  1540.033333    0.500000
# 4               0.333333  11.600000    12.266667     3.000000  226.433333
#
# Destination      36011      36013      36015     36017     36019  ...  \
# 0             0.900000   5.533333   0.000000  0.566667  0.833333  ...
# 1             0.700000   5.133333  13.600000  0.200000  0.000000  ...
# 2             0.600000   0.033333   9.366667  3.966667  1.300000  ...
# 3            14.200000   2.866667  16.433333  8.100000  3.766667  ...
# 4             0.466667  15.933333   1.100000  0.133333  0.033333  ...
#
# Destination     36105      36107      36109      36111     36113     36115  \
# 0            0.666667   0.133333   0.400000  13.600000  8.533333  4.966667
# 1            0.200000   0.233333   2.200000   0.633333  0.033333  0.033333
# 2            9.166667   1.400000   4.633333   5.833333  3.366667  1.533333
# 3            1.266667  38.933333  24.400000   5.200000  0.133333  0.466667
# 4            0.133333   1.433333   2.000000   0.400000  0.000000  0.000000
#
# Destination     36117       36119     36121     36123
# 0            0.366667   18.933333  0.000000  0.133333
# 1            2.433333    1.533333  2.933333  0.633333
# 2            0.266667  562.233333  0.066667  2.000000
# 3            1.866667   18.033333  0.433333  0.166667
# 4            1.733333    1.233333  4.966667  0.233333
#
# [5 rows x 61 columns]

# %% [markdown]
# # Compares it to the Original

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create KDE plot
sns.kdeplot(Pii_ori, label="Real Matrix", fill=True)
sns.kdeplot(Pii_skmob, label="Skmob Generated Matrix", fill=True)

# Labels and legend
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Density Distribution of Pii")
plt.legend()

#Lables and legend
#plt.savefig("Pii_Comparison.png", dpi=300, bbox_inches='tight')

# Show plot
plt.show()

# %% [markdown]
# # Notes

# %% [markdown]
# ### Real Aggredated Mobility
# - Mean: 0.8043316871173353
# - Median: 0.7917201349186358
# - Min: 0.6594295764342875
# - Max: 0.9379360744803336
#
# ### 10,000 Default Tract EPR
# (Last week result), : data = pd.read_csv("../Step7_Sikit_Mobility/NY_Feb26.csv")
# - Mean: 0.478019076596609
# - Median: 0.4728364912386268
# - Min: 0.1384217335058215
# - Max: 0.8917260922367889
#
# ### 5,000 DensityEPR(rho = 0.45, gamma = 0.35)
# - Mean: 0.5386338034917215
# - Median: 0.5212655768457725
# - Min: 0.17
# - Max: 0.9182490051165435
#
# ### 10,000 DensityEPR(rho = 0.4, gamma = 0.4)
# - Mean: 0.5602002706796201
# - Median: 0.5600438959125689
# - Min: 0.24431818181818182
# - Max: 0.9116616412680303
#
# ### 20,000 Density ERP(): Using real populaton data at the Census Tract Level
# - Mean: 0.4527587339921308
# - Median: 0.45253542465020946
# - Min: 0.1537290715372907
# - Max: 0.8960990637060625
#
#
# ## Census Block Group Level
# ### 5,000 DensityEPR()
# - Mean: 0.5319922789226584
# - Median: 0.5621087221305192
# - Min: 0.14606741573033707
# - Max: 0.9118498488945443
#
# ### 20,000 DensityEPR()
# - Mean: 0.5930859602293664
# - Median: 0.6077993963154902
# - Min: 0.25307125307125306
# - Max: 0.9181758314125782
#
# ### 20,000 DensityEPR(rho = 0.5, gamma = 0.3)
# - Mean: 0.5737163347088107
# - Median: 0.5866221271010927
# - Min: 0.21389645776566757
# - Max: 0.9139823008849558
#
# ### 20,000 DensityEPR(rho = 0.4, gamma = 0.4)
# - Mean: 0.6097080838488496
# - Median: 0.6200886287224787
# - Min: 0.19491525423728814
# - Max: 0.9235713944337354
#
# ### 20,000 DensityEPR(rho = 0.45, gamma = 0.35)
# - Mean: 0.59435522825247
# - Median: 0.6069140966664105
# - Min: 0.24043715846994534
# - Max: 0.9244772437743932

# %%
county_group = ori_des_df.groupby(['Origin', 'Destination'])['Count'].sum().reset_index()

Matrix = county_group.pivot_table(index='Origin', 
                                  columns='Destination', 
                                  values= 'Count', fill_value=0)

Matrix = Matrix.reset_index()
Matrix = Matrix.drop(columns = ["Origin"]) #drop the origin column

divisor = [Matrix.iloc[i].sum() for i in range(62)]
average_wt_mt = Matrix.div(divisor, axis=0)

average_wt_mt_np = average_wt_mt.to_numpy()
Pii = [average_wt_mt_np[i][i] for i in range(62)]
Pii
# Out:
# [0.7523463475540466,
#  0.36519674974892724,
#  0.7856426217920215,
#  0.8502835410370471,
#  0.562694185530404,
#  0.5958847736625514,
#  0.8057558630546352,
#  0.7738115668440021,
#  0.43079665947264706,
#  0.8267530936947555,
#  0.46420484236195786,
#  0.6894442050840155,
#  0.35990686328861293,
#  0.6654822815993936,
#  0.9244772437743932,
#  0.42142857142857143,
#  0.5756950584536792,
#  0.7041769408951655,
#  0.5249113064939072,
#  0.3651821862348178,
#  0.24043715846994534,
#  0.6101718213058419,
#  0.7004776072658941,
#  0.8345974947795459,
#  0.31322350845948355,
#  0.423374613003096,
#  0.44074138531152107,
#  0.9150298623439529,
#  0.6036563720269791,
#  0.6614736856915728,
#  0.7853630646083476,
#  0.752057761732852,
#  0.8132058622682146,
#  0.86967607649278,
#  0.539503214272129,
#  0.6798387204800879,
#  0.4195491643995336,
#  0.6172200973574409,
#  0.49086817276897776,
#  0.434765581291261,
#  0.729916409541328,
#  0.5719115497076024,
#  0.6736748742654989,
#  0.661640723601178,
#  0.7381404174573055,
#  0.6402259987543376,
#  0.7875439704158023,
#  0.35538720538720536,
#  0.28898514851485146,
#  0.40128786770086344,
#  0.6341244750625207,
#  0.7648899660543503,
#  0.42122719734660036,
#  0.38891713268937467,
#  0.7292799076434653,
#  0.5373436776285317,
#  0.5357516339869282,
#  0.48171831447778324,
#  0.4810383156793514,
#  0.6479175059307999,
#  0.35823993358239936,
#  0.4315557998900495]
